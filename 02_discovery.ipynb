# %% [markdown]
# # Mock Lifestyle Data Based on Overall Sleep Health
#
# MOCK_SLEEP_DATA.csv was generated using Mockaroo.com, and modeled after the Sleep_health_and_lifestyle_dataset.csv obtained from the Kaggle dataset with the same corresponding name, authored by Laksika Tharmalingam
#
# Data Sources:
#
# - https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# - MOCK_SLEEP_DATA was custom generated via Mockaroo.com

# %%
import pandas as pd

study = pd.read_csv("data/MOCK_SLEEP_DATA.csv")

study.shape
# Out:
# (1000, 21)

# %%
study.head(15)
# Out:
#     id first_name    last_name                            email  \
# 0    1    Desiree      McEllen             dmcellen0@usnews.com
# 1    2       Dona  Francescone      dfrancescone1@tuttocitta.it
# 2    3     Deanna     Reedshaw              dreedshaw2@army.mil
# 3    4    Chelsey      Maxsted               cmaxsted3@time.com
# 4    5     Shadow     Godsmark             sgodsmark4@yandex.ru
# 5    6   Raimundo     Andersch          randersch5@google.co.jp
# 6    7    Atlante     Whittall               awhittall6@php.net
# 7    8    Justinn      Swatton     jswatton7@chicagotribune.com
# 8    9       Dell    Geoghegan  dgeoghegan8@acquirethisname.com
# 9   10       Eben      Hayball              ehayball9@jigsy.com
# 10  11     Camala      Fullerd              cfullerda@wired.com
# 11  12   Lodovico      Poytres              lpoytresb@ifeng.com
# 12  13  Westleigh         Nani                    wnanic@hp.com
# 13  14    Emogene    Rosenboim     erosenboimd@sciencedaily.com
# 14  15       Olia     Tredwell        otredwelle@eventbrite.com
#
#          ip_address  Person ID       Gender  Age  \
# 0    183.48.236.130          4  Genderfluid   49
# 1     231.126.33.94          3       Female   43
# 2   123.171.170.216          7     Bigender   57
# 3   246.148.210.218          5  Genderfluid   26
# 4    117.173.14.104          5         Male   60
# 5   105.149.231.102          2         Male   38
# 6    121.251.149.95          9       Female   53
# 7   145.174.167.219          7  Genderqueer   43
# 8     110.88.55.218          3         Male   34
# 9     184.56.211.84          1      Agender   39
# 10   185.206.206.73          4       Female   57
# 11  207.241.202.144          8         Male   39
# 12   81.217.155.143          9         Male   50
# 13   166.120.73.238          8       Female   38
# 14   241.225.11.169          2       Female   49
#
#                       Occupation  Sleep Duration  ...  \
# 0              Chemical Engineer             6.3  ...
# 1                Cost Accountant             7.5  ...
# 2           Help Desk Technician             6.4  ...
# 3               Health Coach III             9.9  ...
# 4        Assistant Media Planner            10.2  ...
# 5                  Geologist III             7.7  ...
# 6                      Professor             6.5  ...
# 7          VP Product Management             5.4  ...
# 8                        Teacher             7.0  ...
# 9   Structural Analysis Engineer             9.0  ...
# 10             Account Executive             4.3  ...
# 11               Web Developer I             5.0  ...
# 12            Recruiting Manager             5.3  ...
# 13           Associate Professor             5.7  ...
# 14                      Operator             8.9  ...
#
#     Physical Activity Level  Stress Level  BMI Category Blood Pressure  \
# 0                        73             8  Under Weight         145/95
# 1                        48             7  Under Weight         132/87
# 2                        52             2  Under Weight         126/83
# 3                        46             1  Under Weight         125/80
# 4                        52             3    Overweight         132/87
# 5                        74             6  Under Weight         125/80
# 6                        60             9        Normal         125/80
# 7                        64             1         Obese         145/95
# 8                        25             2         Obese         140/90
# 9                        47             8         Obese        150/102
# 10                       72             5        Normal         135/85
# 11                       65             8    Overweight        150/102
# 12                       45             2    Overweight         132/87
# 13                       45             4         Obese         125/80
# 14                       47             8    Overweight         132/87
#
#    Heart Rate  Daily Steps          Sleep Disorder Country of Residence  \
# 0          79         4281                Insomnia          Philippines
# 1          71         2085  Restless Legs Syndrome                China
# 2          90         3365                Insomnia                 Cuba
# 3          91         3359                     NaN               France
# 4          90         6768                     NaN           Azerbaijan
# 5          87         8321       Narcolepsy Type 1            Indonesia
# 6          70         8867                     NaN   Dominican Republic
# 7          92         3802             Sleep Apnea                China
# 8          82         2759  Idiopathic Hypersomnia                China
# 9          87         7067       Narcolepsy Type 2                 Iran
# 10         85         3619  Idiopathic Hypersomnia             Portugal
# 11         75         4106  Idiopathic Hypersomnia                China
# 12         71         2056                Insomnia                Japan
# 13         72         4820  Idiopathic Hypersomnia               Sweden
# 14         87         4724       Narcolepsy Type 1            Indonesia
#
#    Min Sleep Oxygen Saturation  Average Sleep Oxygen Saturation
# 0                         83.2                             91.2
# 1                         88.8                             80.4
# 2                         91.2                             75.9
# 3                         94.6                             92.4
# 4                         68.2                             86.4
# 5                         79.1                             76.2
# 6                         77.2                             80.9
# 7                         85.1                             78.4
# 8                         94.6                             85.4
# 9                         71.4                             86.0
# 10                        94.8                             81.8
# 11                        65.6                             84.4
# 12                        70.8                             94.4
# 13                        89.2                             86.7
# 14                        79.1                             75.6
#
# [15 rows x 21 columns]

# %% [markdown]
# ### Sleep Health Data Dictionary
#
# | Column Name | Type | Description | Cleaning Notes |
# | ----------- | ----- | ----------- | ------------- |
# | id | INTEGER | Row ID Number | Remove, non-quantifiable data |
# | first_name | TEXT | First name of the patient | Remove, non-quantifiable data |
# | last_name | TEXT | Last name of the patient | Remove, non-quantifiable data |
# | email | TEXT | | Remove, non-quantifiable data |
# | ip_address | FLOAT | | Remove, non-quantifiable data |
# | Person ID | INTEGER | | Nonsense parameter, remove
# | Gender | TEXT | Gender of the patient | |
# | Age | INTEGER | Age of the patient | |
# | Occupation | TEXT | Patient's occupation, the goal is to correlate this with the highest level of education once that field is added | Narrow down occupations to the top five based on education level |
# | Sleep Duration | FLOAT | How many hours on average the given patient sleeps at night | |
# | Quality of Sleep | INTEGER | Patients were asked to rate their average quality of sleep from 1 to 10, with 1 feeling like they had no sleep to 10 being exceedingly restorative sleep | |
# | Physical Activity Level | INTEGER | Patients were asked to rate their level of physical activity from 1-100, with 1 being completely bedridden to 100 being active all day inside and outside of work | |
# | Stress Level | INTEGER | Patients were asked to rate their level of stress from 1 to 10, with 1 being a completely relaxed lifestyle to 10 being on the verge of breakdown | |
# | BMI Category | TEXT | Patients were asked so submit their BMI, and corresponding range name for their number was recorded | |
# | Blood Pressure | TEXT | Patients were asked to track their blood pressure and send an average of their findings | |
# | Heart Rate | INTEGER | Patients average heart rate was measured in BPM format and recorded | |
# | Daily Steps | INTEGER | Patients were asked to record their daily steps during a 7 day period, and the average was computed for this study | |
# | Sleep Disorder | TEXT | Patients that have a diagnosed sleep disorder were asked to share, otherwise the field is "Nan" if no sleep disorder was present | Convert Nan fields to present as 'none' |
# | Country of Residence | TEXT | The patient's country of residence | |
# | Min Sleep Oxygen Saturation | FLOAT | Patients were asked to wear a pulse oximeter during sleep, and this is the lowest oxygen saturation recorded during that time | |
# | Average Sleep Oxygen Saturation | FLOAT | Patients were asked to submit their average oxygen saturation during sleep based off of pulse oximeter data | |

# %%
study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               1000 non-null   int64
#  1   first_name                       1000 non-null   object
#  2   last_name                        1000 non-null   object
#  3   email                            1000 non-null   object
#  4   ip_address                       1000 non-null   object
#  5   Person ID                        1000 non-null   int64
#  6   Gender                           1000 non-null   object
#  7   Age                              1000 non-null   int64
#  8   Occupation                       1000 non-null   object
#  9   Sleep Duration                   1000 non-null   float64
#  10  Quality of Sleep                 1000 non-null   int64
#  11  Physical Activity Level          1000 non-null   int64
#  12  Stress Level                     1000 non-null   int64
#  13  BMI Category                     1000 non-null   object
#  14  Blood Pressure                   1000 non-null   object
#  15  Heart Rate                       1000 non-null   int64
#  16  Daily Steps                      1000 non-null   int64
#  17  Sleep Disorder                   855 non-null    object
#  18  Country of Residence             1000 non-null   object
#  19  Min Sleep Oxygen Saturation      1000 non-null   float64
#  20  Average Sleep Oxygen Saturation  1000 non-null   float64
# dtypes: float64(3), int64(8), object(10)
# memory usage: 164.2+ KB

# %%
study["Sleep Disorder"].describe()
# Out:
# count                        855
# unique                         6
# top       Idiopathic Hypersomnia
# freq                         161
# Name: Sleep Disorder, dtype: object

# %%
study["Sleep Disorder"].unique()
# Out:
# array(['Insomnia', 'Restless Legs Syndrome', nan, 'Narcolepsy Type 1',
#        'Sleep Apnea', 'Idiopathic Hypersomnia', 'Narcolepsy Type 2'],
#       dtype=object)

# %%
study["Sleep Disorder"].value_counts()
# Out:
# Sleep Disorder
# Idiopathic Hypersomnia    161
# Narcolepsy Type 2         148
# Sleep Apnea               146
# Insomnia                  140
# Restless Legs Syndrome    131
# Narcolepsy Type 1         129
# Name: count, dtype: int64

# %%
study["Occupation"].unique()
# Out:
# array(['Chemical Engineer', 'Cost Accountant', 'Help Desk Technician',
#        'Health Coach III', 'Assistant Media Planner', 'Geologist III',
#        'Professor', 'VP Product Management', 'Teacher',
#        'Structural Analysis Engineer', 'Account Executive',
#        'Web Developer I', 'Recruiting Manager', 'Associate Professor',
#        'Operator', 'Media Manager III', 'Marketing Assistant',
#        'GIS Technical Architect', 'Administrative Assistant II',
#        'Software Engineer I', 'Programmer III', 'Quality Engineer',
#        'Desktop Support Technician', 'Editor', 'Environmental Specialist',
#        'Office Assistant III', 'Dental Hygienist',
#        'Senior Quality Engineer', 'Research Nurse',
#        'Analog Circuit Design manager', 'Executive Secretary', 'VP Sales',
#        'Biostatistician III', 'Environmental Tech', 'Financial Advisor',
#        'Librarian', 'Speech Pathologist', 'Civil Engineer',
#        'Web Designer I', 'Graphic Designer', 'Tax Accountant',
#        'Engineer I', 'Internal Auditor', 'Developer II', 'Engineer IV',
#        'Senior Sales Associate', 'Database Administrator III',
#        'Director of Sales', 'Safety Technician I', 'Sales Associate',
#        'Data Coordinator', 'Developer I', 'Media Manager IV',
#        'General Manager', 'Business Systems Development Analyst',
#        'Marketing Manager', 'Electrical Engineer', 'Analyst Programmer',
#        'Office Assistant II', 'Account Representative IV',
#        'Nuclear Power Engineer', 'Human Resources Assistant IV',
#        'Financial Analyst', 'Structural Engineer', 'Senior Developer',
#        'Recruiter', 'Systems Administrator II',
#        'Human Resources Assistant I', 'VP Quality Control',
#        'Information Systems Manager', 'Technical Writer', 'Programmer II',
#        'Software Test Engineer II', 'Web Designer IV', 'Social Worker',
#        'Developer IV', 'Human Resources Manager',
#        'Budget/Accounting Analyst IV', 'Web Developer IV', 'VP Marketing',
#        'Payment Adjustment Coordinator', 'Administrative Assistant I',
#        'Software Consultant', 'Nurse Practicioner', 'Account Coordinator',
#        'Accountant I', 'Software Test Engineer III', 'Health Coach II',
#        'Health Coach IV', 'Mechanical Systems Engineer',
#        'Systems Administrator IV', 'Project Manager',
#        'Administrative Assistant IV', 'Actuary', 'Pharmacist',
#        'Web Developer II', 'Geologist IV', 'Physical Therapy Assistant',
#        'Research Associate', 'Food Chemist', 'Safety Technician III',
#        'Compensation Analyst', 'Junior Executive',
#        'Accounting Assistant III', 'Registered Nurse',
#        'Biostatistician II', 'Legal Assistant', 'Administrative Officer',
#        'Product Engineer', 'Sales Representative', 'Senior Editor',
#        'Biostatistician I', 'Software Test Engineer IV',
#        'Account Representative II', 'Occupational Therapist',
#        'Senior Cost Accountant', 'Accountant IV', 'Assistant Manager',
#        'Geologist II', 'Research Assistant I', 'Programmer Analyst I',
#        'Help Desk Operator', 'Automation Specialist I',
#        'Automation Specialist IV', 'Chief Design Engineer',
#        'Software Engineer IV', 'Staff Accountant II',
#        'Safety Technician IV', 'Staff Scientist', 'Media Manager II',
#        'Systems Administrator III', 'Accounting Assistant II', 'Nurse',
#        'Paralegal', 'Assistant Professor', 'Web Developer III',
#        'VP Accounting', 'Computer Systems Analyst III',
#        'Community Outreach Specialist', 'Health Coach I',
#        'Budget/Accounting Analyst II', 'Accountant II', 'Statistician IV',
#        'Budget/Accounting Analyst III', 'Database Administrator II',
#        'Research Assistant IV', 'Human Resources Assistant II',
#        'Research Assistant III', 'Administrative Assistant III',
#        'Clinical Specialist', 'Safety Technician II', 'Statistician I',
#        'Computer Systems Analyst I', 'Quality Control Specialist',
#        'Geological Engineer', 'Account Representative I',
#        'Design Engineer', 'Software Engineer II',
#        'Accounting Assistant I', 'Computer Systems Analyst IV',
#        'Database Administrator IV', 'Computer Systems Analyst II',
#        'Office Assistant I', 'Programmer Analyst II',
#        'Senior Financial Analyst', 'Statistician II',
#        'Staff Accountant III', 'Programmer Analyst III', 'Developer III',
#        'Budget/Accounting Analyst I', 'Web Designer II', 'Programmer I',
#        'Staff Accountant I', 'Database Administrator I', 'Programmer IV',
#        'Engineer II', 'Human Resources Assistant III',
#        'Programmer Analyst IV', 'Research Assistant II',
#        'Systems Administrator I', 'Software Engineer III',
#        'Automation Specialist II', 'Accounting Assistant IV',
#        'Software Test Engineer I', 'Office Assistant IV',
#        'Web Designer III', 'Media Manager I',
#        'Account Representative III', 'Engineer III'], dtype=object)

# %%
study["Occupation"].value_counts()
# Out:
# Occupation
# Teacher                           16
# Analyst Programmer                15
# Payment Adjustment Coordinator    14
# Structural Analysis Engineer      14
# Account Executive                 14
#                                   ..
# Software Test Engineer III         1
# Statistician I                     1
# Safety Technician II               1
# Safety Technician I                1
# Engineer III                       1
# Name: count, Length: 189, dtype: int64

# %%
study["Country of Residence"].unique()
# Out:
# array(['Philippines', 'China', 'Cuba', 'France', 'Azerbaijan',
#        'Indonesia', 'Dominican Republic', 'Iran', 'Portugal', 'Japan',
#        'Sweden', 'Poland', 'United States', 'Russia', 'Czech Republic',
#        'Greece', 'Canada', 'South Korea', 'Latvia', 'Honduras',
#        'Bangladesh', 'Nigeria', 'Mozambique', 'Mexico', 'Brazil', 'Spain',
#        'Serbia', 'Comoros', 'Thailand', 'Malaysia', 'Uruguay', 'Libya',
#        'Morocco', 'Macedonia', 'Argentina', 'Mongolia', 'Lebanon',
#        'Denmark', 'New Zealand', 'Norway', 'Cameroon', 'Ecuador',
#        'Sri Lanka', 'Netherlands', 'Colombia', 'Ethiopia', 'Georgia',
#        'Bolivia', 'Gambia', 'Ivory Coast', 'Namibia', 'Guatemala',
#        'Saint Kitts and Nevis', 'Tunisia', 'Israel', 'Vietnam', 'Peru',
#        'Bulgaria', 'South Africa', 'Zimbabwe', 'Ukraine', 'Syria',
#        'Albania', 'Madagascar', 'Finland', 'Pakistan', 'Venezuela',
#        'Moldova', 'Malta', 'Kazakhstan', 'El Salvador', 'United Kingdom',
#        'Tajikistan', 'Ireland', 'North Korea', 'Lithuania', 'Croatia',
#        'Belarus', 'Costa Rica', 'Kosovo', 'Germany', 'French Polynesia',
#        'East Timor', 'Vanuatu', 'Burundi', 'Gabon', 'Uganda', 'Paraguay',
#        'Dominica', 'Guinea', 'Mayotte', 'Saudi Arabia', 'Armenia',
#        'Botswana', 'Liberia', 'Luxembourg', 'Sudan',
#        'Bosnia and Herzegovina', 'Nicaragua', 'Bahamas', 'Myanmar',
#        'Niger', 'Swaziland', 'Estonia', 'Burkina Faso', 'Chad', 'Benin',
#        'Afghanistan', 'Romania', 'Uzbekistan', 'Jamaica', 'Kenya',
#        'Faroe Islands', 'United Arab Emirates', 'Equatorial Guinea',
#        'Palestinian Territory', 'Chile', 'Yemen', 'Tanzania',
#        'British Virgin Islands', 'Somalia', 'Sierra Leone'], dtype=object)

# %%
study["Country of Residence"].value_counts()
# Out:
# Country of Residence
# China           198
# Indonesia       103
# Russia           60
# Philippines      57
# Brazil           40
#                ...
# Namibia           1
# Gambia            1
# Liberia           1
# Sudan             1
# Sierra Leone      1
# Name: count, Length: 122, dtype: int64

# %%
study["BMI Category"].unique()
# Out:
# array(['Under Weight', 'Overweight', 'Normal', 'Obese'], dtype=object)

# %%
study["BMI Category"].value_counts()
# Out:
# BMI Category
# Overweight      272
# Obese           265
# Normal          239
# Under Weight    224
# Name: count, dtype: int64

# %% [markdown]
# ## Questions:
#
# - Which career is the most common for individuals that are affected by a sleeo disorder?
# - How do sleep disorders contribute to stress levels vs others without a sleep disorder?
# - Do overweight individuals with sleep disorders experience more stress?
# - Which gender is more likely to have higher stress levels due to sleep disorders?
# - Which career(s) are more stressful with sleep disorders?
# - Does a higher physical activity level make you less likely to have a sleep disorder?
# - Do those with sleep disorders earn more, less or the same as those without sleep disorders?
# - Does having a sleep disorder present a barrier to higher education?
# - Do certain countries have higher rates of sleep disorders vs the average?
#
# ## Fields Needed
# - Education Level
# - Salaries with preset ranges that correspond to education levels
